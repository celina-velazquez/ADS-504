# %% [markdown]
# <a href="https://colab.research.google.com/github/celina-velazquez/ADS-504/blob/main/Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This section of code imports the libraries required for this script.

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

# %%
def take_photo(filename='photo.jpg', quality=0.8): # This section gives access to the web camera and saves the file as photo.jpg.
  js = Javascript(''' // this creates a variable from a javascript function. The three apostrophes denote that there will be more than one line.
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button'); // Creates a button and assigns it to the capture variable.
      capture.textContent = 'Capture'; // This adds text to the button.
      div.appendChild(capture); // This makes the button visible.

      const video = document.createElement('video'); // Creates a video element.
      video.style.display = 'block'; // This creates a block of the video element.

      const stream = await navigator.mediaDevices.getUserMedia({video: true}); // This asks the user for permission to turn on the video camera.

// This section adds the video to the video element and displays the video element in a container and plays the video.
      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // This resizes the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // This waits for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      // This creates a variable called canvas and a canvas is assigned to it.
      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth; // This tells the canvas to be as wide as the video.
      canvas.height = video.videoHeight; // This tells the canvas to be as tall as the video.
      canvas.getContext('2d').drawImage(video, 0, 0); // This creates a 2-dimensional image.
      stream.getVideoTracks()[0].stop(); // This turns off the video camera.
      div.remove(); // This removes the canvas
      return canvas.toDataURL('image/jpeg', quality); // Creates an output of a jpeg image.
    }
    ''')
  display(js) # This displays the image we took in the section of code prior to this one.
  data = eval_js('takePhoto({})'.format(quality)) # This runs the takePhoto function.
  binary = b64decode(data.split(',')[1]) # Decodes a b64-encoded bytes-like object and returns a bytes object.
  with open(filename, 'wb') as f: # Opens a file to write binary to it
    f.write(binary) # Writes binary to a file
  return filename # Displays the file name

from IPython.display import Image # Calls the library we need.
try:
  filename = take_photo() # Assigns the photo we took using the take_photo() function to the filename variable.
  print('Saved to {}'.format(filename)) # Shows where the image was saved to.

  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %% [markdown]
# This section of code imports the libraries required to run this section of code.

# %%
# This section imports the necessary libraries
import cv2
import numpy as np
import imutils
from google.colab.patches import cv2_imshow

# This section downloads the files from the specified locations.
# !wget -N https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget -N https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel

# Prints the designated text or assigs text to designated variables.
print("[INFO] loading model...")
prototxt = 'deploy.prototxt'
model = 'res10_300x300_ssd_iter_140000.caffemodel'

# This loads a deep neural network (DNN), using the prototext network architecture and the caffemodel.
net = cv2.dnn.readNetFromCaffe(prototxt, model)

# Assign the image to the image variable
image = cv2.imread("photo.jpg")

# Image array
(h, w) = image.shape[:2]

# resize it to have a maximum width of 400 pixels
image = imutils.resize(image, width=400)

# Resizes the image to a square of 300 x 300 pixels and turns it into a blob.
blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0))

# Print text
print("[INFO] computing object detections...")

# Assigns blob to the deep neural network.
net.setInput(blob)

# Runs a forward pass on the neural network, net.
detections = net.forward()

for i in range(0, detections.shape[2]):
    # extract the confidence (i.e., probability) associated with the prediction
    confidence = detections[0, 0, i, 2]
    # filter out weak detections by ensuring the `confidence` is
    # greater than the minimum confidence threshold
    if confidence > 0.5:
        # compute the (x, y)-coordinates of the bounding box for the object
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        (startX, startY, endX, endY) = box.astype("int")
        # draw the bounding box of the face along with the associated probability
        text = "{:.2f}%".format(confidence * 100)

        # Formatting for the rectangle and image
        y = startY - 10 if startY - 10 > 10 else startY + 10
        cv2.rectangle(image, (startX, startY), (endX, endY), (0, 0, 255), 2)
        cv2.putText(image, text, (startX, y),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)

cv2_imshow(image)
# Out:
# --2025-08-05 02:37:41--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt’
#
# deploy.prototxt     100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-08-05 02:37:41 (16.3 MB/s) - ‘deploy.prototxt’ saved [28104/28104]
#
# --2025-08-05 02:37:41--  https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...
